# %% [markdown]
# # Facial Keypoints Detection

# %%
# imports
import sys
sys.path.append('..')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms, models
from utils.eda import show_image_with_keypoints, get_image_and_keypoints_from_observation, visualize_duplicates
# preprocessing
from preprocessor.preprocessor import Preprocessor
from torch_dataset.facial_keypoints_dataset import FacialKeypointsDataset
# augmentation
from augmentor.edge_detection.edge_detection import EdgeDetection
from augmentor.image_blurring.image_blurring import ImageBlurring
from augmentor.image_brightness.image_brightness import ImageBrightness
from augmentor.image_flip.image_flip import ImageFlip
from augmentor.image_rotation.image_rotation import ImageRotation
from augmentor.image_sharpening.image_sharpening import ImageSharpening
from augmentor.image_translation.image_translation import ImageTranslation
from augmentor.image_to_tensor.image_to_tensor import ImageToTensor

# %% [markdown]
# ## Load data

# %%
df_train = pd.read_csv('../data/training.csv')
df_test = pd.read_csv('../data/test.csv')

# %%
df_train.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# 1                70.722723                36.187166                 36.034723
# 2                70.984421                36.320968                 37.678105
# 3                72.314713                38.380967                 37.618643
# 4                72.515926                39.884466                 36.982380
#
#    right_eye_inner_corner_y  ...  nose_tip_y  mouth_left_corner_x  \
# 0                 37.389402  ...   57.066803            61.195308
# 1                 34.361532  ...   55.660936            56.421447
# 2                 36.320968  ...   53.538947            60.822947
# 3                 38.754115  ...   54.166539            65.598887
# 4                 39.094852  ...   64.889521            60.671411
#
#    mouth_left_corner_y  mouth_right_corner_x  mouth_right_corner_y  \
# 0            79.970165             28.614496             77.388992
# 1            76.352000             35.122383             76.047660
# 2            73.014316             33.726316             72.732000
# 3            72.703722             37.245496             74.195478
# 4            77.523239             31.191755             76.997301
#
#    mouth_center_top_lip_x  mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# 0               43.312602               72.935459                  43.130707
# 1               46.684596               70.266553                  45.467915
# 2               47.274947               70.191789                  47.274947
# 3               50.303165               70.091687                  51.561183
# 4               44.962748               73.707387                  44.227141
#
#    mouth_center_bottom_lip_y  \
# 0                  84.485774
# 1                  85.480170
# 2                  78.659368
# 3                  78.268383
# 4                  86.871166
#
#                                                Image
# 0  238 236 237 238 240 240 239 241 241 243 240 23...
# 1  219 215 204 196 204 211 212 200 180 168 178 19...
# 2  144 142 159 180 188 188 184 180 167 132 84 59 ...
# 3  193 192 193 194 194 194 193 192 168 111 50 12 ...
# 4  147 148 160 196 215 214 216 217 219 220 206 18...
#
# [5 rows x 31 columns]

# %%
df_test.head()
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Basic info

# %%
print('shape of train dataset: ', df_train.shape)
print('shape of test dataset: ', df_test.shape)
# Out:
# shape of train dataset:  (7049, 31)
# shape of test dataset:  (1783, 2)

# %% [markdown]
# Columns and their types in df_train:
#
# -left(right)_eye_center_x(y) - x(y) coordinate of location of center of left(right) eye on image - float,
#
# -left(right)_eye_inner_corner_x(y) - x(y) coordinate of location of inner corner of left(right) eye - float,
#
# -left(right)_eye_outer_corner_x(y) - x(y) coordinate of location of outer corner of left(right) eye - float,
#
# -left(right)_eyebrow_inner_end_x(y) - x(y) coordinate of location of inner end of left(right) eyebrow - float,
#
# -left(right)_eyebrow_outer_end_x(y) - x(y) coordinate of location of outer end of left(right) eyebrow - float,
#
# -nose_tip_x(y) - x(y) coordinate of tip of nose - float,
#
# -mouth_left(right)_corner_x(y) - x(y) coordinate of location of left(right) corner of mouth - float,
#
# -mouth_center_top(bottom)_lip_x(y) - x(y) coordinate of top(bottom) center of mouth - float,
#
# -Image - matrix representing image - matrix

# %% [markdown]
# ### Example visualisation

# %%
images, keypoints = get_image_and_keypoints_from_observation(df_train.iloc[0], preprocess=True)
show_image_with_keypoints(images, keypoints)

# %% [markdown]
# ### Missing values

# %%
df_train.isna().sum().sort_values(ascending=False)
# Out:
# left_eyebrow_outer_end_y     4824
# left_eyebrow_outer_end_x     4824
# right_eyebrow_outer_end_y    4813
# right_eyebrow_outer_end_x    4813
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# mouth_left_corner_y          4780
# mouth_left_corner_x          4780
# right_eyebrow_inner_end_x    4779
# mouth_right_corner_x         4779
# right_eyebrow_inner_end_y    4779
# left_eyebrow_inner_end_y     4779
# left_eyebrow_inner_end_x     4779
# mouth_right_corner_y         4779
# left_eye_inner_corner_y      4778
# left_eye_inner_corner_x      4778
# mouth_center_top_lip_x       4774
# mouth_center_top_lip_y       4774
# mouth_center_bottom_lip_y      33
# mouth_center_bottom_lip_x      33
# right_eye_center_y             13
# right_eye_center_x             13
# left_eye_center_x              10
# left_eye_center_y              10
# nose_tip_y                      0
# nose_tip_x                      0
# Image                           0
# dtype: int64

# %% [markdown]
# There are a lot of missing values in the data, especially in more sophisticated features. We can impute them using other models, or just ignore the value of loss function for them. Since all the missing values appear in target variables, for now we will not impute them, and rather just omit calculating loss for these observations. Hence, no actions will be taken as of now.

# %%
def MSELoss(output, target):
    filter = ~torch.isnan(target)
    return ((output[filter] - target[filter]) ** 2).mean()

# %% [markdown]
# ### Duplicates

# %%
duplicates_count = df_train.duplicated(subset = 'Image', keep='last').sum()
print(f'There are {duplicates_count} duplicates in the dataset.')
# Out:
# There are 555 duplicates in the dataset.

# %%
visualize_duplicates(df_train)

# %% [markdown]
# There is no clear automatic way of picking better option. Thus, the best way would be to calculate some sort of aggregate for every feature. For lack of a better candidate, let's go with the mean value.

# %% [markdown]
# ## Preprocessing

# %%
preprocessor_train = Preprocessor(df_train)
preprocessor_test = Preprocessor(df_test)

# %%
print('Preprocessing train dataset..')
preprocessor_train.preprocess_dataset()
df_train = preprocessor_train.df
# Out:
# Preprocessing train dataset..
# Handling duplicates...done.
# Transforming image column...done.

# %%
print('Preprocessing test dataset..')
df_test = preprocessor_test.preprocess_dataset()
df_test = preprocessor_test.df
# Out:
# Preprocessing test dataset..
# Handling duplicates...done.
# Transforming image column...done.

# %%
print("shape of the train dataset after preprocessing: ", df_train.shape)
print("shape of the test dataset after preprocessing: ", df_test.shape)
# Out:
# shape of the train dataset after preprocessing:  (6494, 31)
# shape of the test dataset after preprocessing:  (1752, 2)

# %% [markdown]
# ### Visualizations after preprocessing

# %%
fig = plt.figure(figsize=(16,16))
for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    image, keypoints = get_image_and_keypoints_from_observation(df_train.iloc[i])
    show_image_with_keypoints(image, keypoints)

# %% [markdown]
# ## Creating torch dataset

# %%
dataset = FacialKeypointsDataset(df_train)
print("Number of observations in training set: ", len(dataset))
datapoint = dataset[0]
img = datapoint['image']
keypoints = datapoint['keypoints']
plt.imshow(img, cmap='gray')
plt.plot(keypoints[0::2], keypoints[1::2], 'gx')
plt.title("Example observation")
plt.show()
# Out:
# Number of observations in training set:  6494

# %% [markdown]
# ## Data augmentation

# %%
show_image_with_keypoints(datapoint["image"], datapoint["keypoints"].reshape(15,2))

# %%
image, keypoints = datapoint["image"], datapoint["keypoints"]
keypoints_columns = df_train.columns[:-1]
random_flip = ImageFlip(probability_threshold=1.0)
random_rotation = ImageRotation(angle=45, probability_threshold=1.0)
random_translation = ImageTranslation(translation_params = (0.1, 0.1), probability_threshold=1.0)
random_brightness = ImageBrightness(brightness=0.2, probability_threshold=1.0)
random_sharpening = ImageSharpening(probability_threshold=1.0)
random_blurring = ImageBlurring(ksize = (5, 5), probability_threshold=1.0)
random_edge_sharpening = EdgeDetection(probability_threshold=1.0)

transform_flip = random_flip(datapoint)
transform_rotation = random_rotation(datapoint)
transform_translation = random_translation(datapoint)
transform_combined = random_flip(random_rotation(random_translation(datapoint)))
transform_brightness = random_brightness(datapoint)
transform_sharpening = random_sharpening(datapoint)
transform_blurring = random_blurring(datapoint)
transform_edge_sharpening = random_edge_sharpening(datapoint)

transforms_list = [transform_flip, transform_rotation, transform_translation, transform_combined, transform_brightness, transform_sharpening,
                   transform_blurring, transform_edge_sharpening]

for transformed_image_with_keypoints in transforms_list:
    transformed_image = transformed_image_with_keypoints["image"]
    transformed_keypoints = transformed_image_with_keypoints["keypoints"]

    fig = plt.figure(figsize=(10, 20))
    # Plot original image
    fig.add_subplot(1, 2, 1)
    plt.imshow(image, cmap='gray')
    for i, keypoint_name in enumerate(keypoints_columns[::2]):
        plt.annotate(keypoint_name[:-2],
                     (keypoints[2 * i], keypoints[2 * i + 1]),
                     fontsize='xx-small')
    plt.plot(keypoints.reshape((15, 2))[:, 0],
             keypoints.reshape((15, 2))[:, 1], 'gx')
    # Plot flipped image
    fig.add_subplot(1, 2, 2)
    plt.imshow(transformed_image, cmap='gray')
    for i, keypoint_name in enumerate(keypoints_columns[::2]):
        plt.annotate(keypoint_name[:-2],
                     (transformed_keypoints[2 * i], transformed_keypoints[2 * i + 1]),
                     fontsize='xx-small')
    plt.plot(transformed_keypoints.reshape((15, 2))[:, 0],
             transformed_keypoints.reshape((15, 2))[:, 1], 'gx')

    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Transformations

# %%
train_transform = torchvision.transforms.Compose([
     EdgeDetection(probability_threshold=0.33),
     ImageBlurring(ksize = (5, 5), probability_threshold=0.25),
     ImageBrightness(brightness=0.2, probability_threshold=0.5),
     ImageFlip(probability_threshold=0.5),
     ImageRotation(angle=45, probability_threshold=0.33),
     ImageSharpening(probability_threshold=0.5),
     ImageTranslation(translation_params = (0.1, 0.1), probability_threshold=0.33),
     ImageToTensor()
     ])

val_transform = torchvision.transforms.Compose([ImageToTensor()])

# %% [markdown]
# ## Modeling

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ### Model

# %%
# model = torchvision.models.densenet121(weights=torchvision.models.DenseNet121_Weights.DEFAULT)
# model
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to C:\Users\User/.cache\torch\hub\checkpoints\densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 33.4MB/s]
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
class ModelCNN(torch.nn.Module):
    def __init__(self, in_channels=3, out_channels=30):
        super(ModelCNN,self).__init__()
        self.model = torch.nn.Sequential(
            torch.nn.Conv2d(3,64, kernel_size=3, stride=1),
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            
            torch.nn.Conv2d(64,128, kernel_size=3, stride=1),
            torch.nn.Dropout(0.3),
            torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            
            torch.nn.Conv2d(128,256, kernel_size=3, stride=1),
            torch.nn.Dropout(0.3),
            torch.nn.BatchNorm2d(256),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            
            torch.nn.Conv2d(256,512, kernel_size=3, stride=1),
            torch.nn.Dropout(0.3),
            torch.nn.BatchNorm2d(512),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            
            torch.nn.Conv2d(512,1024, kernel_size=3, stride=1),
            torch.nn.Dropout(0.3),
            torch.nn.BatchNorm2d(1024),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(2),
            
            torch.nn.Flatten(),
            
            torch.nn.Linear(1024, 512),
            torch.nn.Dropout(0.3),
            torch.nn.BatchNorm1d(512),
            torch.nn.ReLU(),
            
            torch.nn.Linear(512, out_channels)
            
        )
    
    def forward(self, x):
        x = self.model(x)
        return x

# %%
model = ModelCNN()

# %%
# prevents backproping through parameters
# for param in model.parameters():
#     param.requires_grad = False

# model.classifier = nn.Sequential(nn.Linear(1024, 256),
#                                  nn.ReLU(),
#                                  nn.Dropout(0.2),
#                                  nn.Linear(256, 30),
#                                  nn.LogSoftmax(dim=1))

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.model.parameters(), lr=0.0001)

model.to(device)
# Out:
# ModelCNN(
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (5): Dropout(p=0.3, inplace=False)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (10): Dropout(p=0.3, inplace=False)
#     (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#     (15): Dropout(p=0.3, inplace=False)
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1))
#     (20): Dropout(p=0.3, inplace=False)
#     (21): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Flatten(start_dim=1, end_dim=-1)
#     (25): Linear(in_features=1024, out_features=512, bias=True)
#     (26): Dropout(p=0.3, inplace=False)
#     (27): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (28): ReLU()
#     (29): Linear(in_features=512, out_features=30, bias=True)
#   )
# )

# %% [markdown]
# ### Dataset

# %%
train_size = int(len(dataset) * 0.85)
val_size = len(dataset) - train_size
train_set, val_set = torch.utils.data.random_split(dataset, [train_size, val_size])

train_set.dataset.transforms = train_transform
val_set.dataset.transforms = val_transform

train_loader = torch.utils.data.DataLoader(train_set, shuffle=True, batch_size=32)
val_loader = torch.utils.data.DataLoader(val_set, shuffle=True, batch_size=32)

# %% [markdown]
# ### Train the model

# %%
torch.save(model.state_dict(), "./custom_model_200.pth")

# %%
# model = TheModelClass(*args, **kwargs)
# model.load_state_dict(torch.load("./custom_model.pth"))
# model.eval()

# %%
n_epochs = 200
train_steps = len(train_set) / 32
val_steps = len(val_set) / 32


for epoch in range(1, n_epochs+1):
    torch.manual_seed(epoch)

    print(f"EPOCH: {epoch}/{n_epochs}")

    train_loss = 0.0
    model.model.train()
    
    for (batch_idx, sample) in enumerate(train_loader):
        x = sample['image']
        y = sample['keypoints']
        (x, y) = (x.to(device), y.to(device))
        pred = model.model(x)
        loss = MSELoss(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss
    
    with torch.no_grad():
        model.model.eval()
        val_loss = 0.0
        for val_sample in val_loader:
            x = val_sample['image']
            y = val_sample['keypoints']
            (x, y) = (x.to(device), y.to(device))
            pred = model.model(x)
            val_loss += MSELoss(pred, y)

    avg_train_loss = train_loss / train_steps
    avg_val_loss = val_loss / val_steps

    print(f"Average train loss: {avg_train_loss:.6f}, Average validation loss: {avg_val_loss:.6f}")
# Out:
# EPOCH: 1/200
# Average train loss: 2475.813477, Average validation loss: 2642.202637
# EPOCH: 2/200
# Average train loss: 1967.384155, Average validation loss: 2564.671387
# EPOCH: 3/200
# Average train loss: 1542.996338, Average validation loss: 2315.795654
# EPOCH: 4/200
# Average train loss: 1215.265259, Average validation loss: 2048.148926
# EPOCH: 5/200
# Average train loss: 955.271423, Average validation loss: 1765.503662
# EPOCH: 6/200
# Average train loss: 746.460632, Average validation loss: 1760.910278
# EPOCH: 7/200
# Average train loss: 577.574402, Average validation loss: 1299.743042
# EPOCH: 8/200
# Average train loss: 430.967255, Average validation loss: 1047.887451
# EPOCH: 9/200
# Average train loss: 306.426971, Average validation loss: 803.062134
# EPOCH: 10/200
# Average train loss: 210.993134, Average validation loss: 785.525085
# EPOCH: 11/200
# Average train loss: 145.345688, Average validation loss: 660.327332
# EPOCH: 12/200
# Average train loss: 99.236458, Average validation loss: 630.152954
# EPOCH: 13/200
# Average train loss: 68.207916, Average validation loss: 637.322937
# EPOCH: 14/200
# Average train loss: 48.974411, Average validation loss: 566.429932
# EPOCH: 15/200
# Average train loss: 37.046986, Average validation loss: 581.648987
# EPOCH: 16/200
# Average train loss: 30.035585, Average validation loss: 589.123657
# EPOCH: 17/200
# Average train loss: 25.304371, Average validation loss: 601.308594
# EPOCH: 18/200
# Average train loss: 22.384970, Average validation loss: 569.443115
# EPOCH: 19/200
# Average train loss: 21.012627, Average validation loss: 596.497070
# EPOCH: 20/200
# Average train loss: 19.363878, Average validation loss: 556.993652
# EPOCH: 21/200
# Average train loss: 18.806240, Average validation loss: 580.037659
# EPOCH: 22/200
# Average train loss: 18.247244, Average validation loss: 563.119751
# EPOCH: 23/200
# Average train loss: 18.013912, Average validation loss: 482.587891
# EPOCH: 24/200
# Average train loss: 17.533651, Average validation loss: 511.828583
# EPOCH: 25/200
# Average train loss: 17.126480, Average validation loss: 510.340057
# EPOCH: 26/200
# Average train loss: 17.142073, Average validation loss: 564.653809
# EPOCH: 27/200
# Average train loss: 16.445480, Average validation loss: 467.829346
# EPOCH: 28/200
# Average train loss: 15.934755, Average validation loss: 500.763489
# EPOCH: 29/200
# Average train loss: 15.696985, Average validation loss: 454.057617
# EPOCH: 30/200
# Average train loss: 15.224960, Average validation loss: 475.466827
# EPOCH: 31/200
# Average train loss: 15.216432, Average validation loss: 393.655792
# EPOCH: 32/200
# Average train loss: 15.029379, Average validation loss: 348.813599
# EPOCH: 33/200
# Average train loss: 14.398309, Average validation loss: 424.155334
# EPOCH: 34/200
# Average train loss: 13.998161, Average validation loss: 417.570251
# EPOCH: 35/200
# Average train loss: 13.559065, Average validation loss: 422.506042
# EPOCH: 36/200
# Average train loss: 12.718723, Average validation loss: 435.719849
# EPOCH: 37/200
# Average train loss: 12.298369, Average validation loss: 510.296417
# EPOCH: 38/200
# Average train loss: 12.183043, Average validation loss: 526.774109
# EPOCH: 39/200
# Average train loss: 12.178328, Average validation loss: 385.294617
# EPOCH: 40/200
# Average train loss: 11.514078, Average validation loss: 494.787659
# EPOCH: 41/200
# Average train loss: 11.460431, Average validation loss: 442.321350
# EPOCH: 42/200
# Average train loss: 11.392227, Average validation loss: 480.889069
# EPOCH: 43/200
# Average train loss: 10.864331, Average validation loss: 465.462158
# EPOCH: 44/200
# Average train loss: 10.921793, Average validation loss: 412.722076
# EPOCH: 45/200
# Average train loss: 10.439059, Average validation loss: 418.573730
# EPOCH: 46/200
# Average train loss: 10.294600, Average validation loss: 449.057983
# EPOCH: 47/200
# Average train loss: 9.996422, Average validation loss: 409.859039
# EPOCH: 48/200
# Average train loss: 9.797406, Average validation loss: 408.855103
# EPOCH: 49/200
# Average train loss: 9.803666, Average validation loss: 449.743805
# EPOCH: 50/200
# Average train loss: 9.752135, Average validation loss: 437.136627
# EPOCH: 51/200
# Average train loss: 9.545434, Average validation loss: 355.181366
# EPOCH: 52/200
# Average train loss: 9.194008, Average validation loss: 370.709412
# EPOCH: 53/200
# Average train loss: 9.051987, Average validation loss: 357.149323
# EPOCH: 54/200
# Average train loss: 9.118148, Average validation loss: 403.738342
# EPOCH: 55/200
# Average train loss: 8.707880, Average validation loss: 394.267090
# EPOCH: 56/200
# Average train loss: 8.745783, Average validation loss: 413.090546
# EPOCH: 57/200
# Average train loss: 8.732436, Average validation loss: 408.198730
# EPOCH: 58/200
# Average train loss: 8.415616, Average validation loss: 418.980957
# EPOCH: 59/200
# Average train loss: 8.457012, Average validation loss: 364.500763
# EPOCH: 60/200
# Average train loss: 8.183106, Average validation loss: 397.835907
# EPOCH: 61/200
# Average train loss: 8.250012, Average validation loss: 288.419769
# EPOCH: 62/200
# Average train loss: 7.847988, Average validation loss: 382.322968
# EPOCH: 63/200
# Average train loss: 7.920023, Average validation loss: 360.787506
# EPOCH: 64/200
# Average train loss: 7.974467, Average validation loss: 399.096985
# EPOCH: 65/200
# Average train loss: 7.756290, Average validation loss: 333.848236
# EPOCH: 66/200
# Average train loss: 7.536214, Average validation loss: 364.484924
# EPOCH: 67/200
# Average train loss: 7.588963, Average validation loss: 410.259277
# EPOCH: 68/200
# Average train loss: 7.531121, Average validation loss: 356.071991
# EPOCH: 69/200
# Average train loss: 7.666667, Average validation loss: 280.744080
# EPOCH: 70/200
# Average train loss: 7.605525, Average validation loss: 335.886963
# EPOCH: 71/200
# Average train loss: 7.318738, Average validation loss: 368.433655
# EPOCH: 72/200
# Average train loss: 7.271377, Average validation loss: 324.132233
# EPOCH: 73/200
# Average train loss: 7.433560, Average validation loss: 337.844879
# EPOCH: 74/200
# Average train loss: 7.423208, Average validation loss: 419.722565
# EPOCH: 75/200
# Average train loss: 7.131383, Average validation loss: 357.541107
# EPOCH: 76/200
# Average train loss: 7.102870, Average validation loss: 389.319031
# EPOCH: 77/200
# Average train loss: 7.276090, Average validation loss: 373.960999
# EPOCH: 78/200
# Average train loss: 7.122335, Average validation loss: 384.365967
# EPOCH: 79/200
# Average train loss: 6.844632, Average validation loss: 350.475525
# EPOCH: 80/200
# Average train loss: 6.922287, Average validation loss: 331.750580
# EPOCH: 81/200
# Average train loss: 6.869207, Average validation loss: 284.731293
# EPOCH: 82/200
# Average train loss: 6.609050, Average validation loss: 312.125549
# EPOCH: 83/200
# Average train loss: 6.575860, Average validation loss: 300.140320
# EPOCH: 84/200
# Average train loss: 6.608616, Average validation loss: 298.991821
# EPOCH: 85/200
# Average train loss: 6.534472, Average validation loss: 350.356232
# EPOCH: 86/200
# Average train loss: 6.499255, Average validation loss: 287.090912
# EPOCH: 87/200
# Average train loss: 6.609081, Average validation loss: 405.937866
# EPOCH: 88/200
# Average train loss: 6.516402, Average validation loss: 331.125153
# EPOCH: 89/200
# Average train loss: 6.491351, Average validation loss: 353.039642
# EPOCH: 90/200
# Average train loss: 6.569802, Average validation loss: 367.520569
# EPOCH: 91/200
# Average train loss: 6.294963, Average validation loss: 343.109985
# EPOCH: 92/200
# Average train loss: 6.215709, Average validation loss: 270.795380
# EPOCH: 93/200
# Average train loss: 6.491277, Average validation loss: 317.396606
# EPOCH: 94/200
# Average train loss: 6.180207, Average validation loss: 286.867004
# EPOCH: 95/200
# Average train loss: 6.198207, Average validation loss: 278.005615
# EPOCH: 96/200
# Average train loss: 6.286882, Average validation loss: 271.140778
# EPOCH: 97/200
# Average train loss: 6.299369, Average validation loss: 268.926117
# EPOCH: 98/200
# Average train loss: 6.159396, Average validation loss: 300.592896
# EPOCH: 99/200
# Average train loss: 5.910229, Average validation loss: 293.980652
# EPOCH: 100/200
# Average train loss: 6.124534, Average validation loss: 346.189392
# EPOCH: 101/200
# Average train loss: 6.100172, Average validation loss: 378.863495
# EPOCH: 102/200
# Average train loss: 6.074125, Average validation loss: 335.232849
# EPOCH: 103/200
# Average train loss: 6.143792, Average validation loss: 379.459656
# EPOCH: 104/200
# Average train loss: 5.960907, Average validation loss: 290.163177
# EPOCH: 105/200
# Average train loss: 5.949343, Average validation loss: 338.750977
# EPOCH: 106/200
# Average train loss: 5.856293, Average validation loss: 267.495697
# EPOCH: 107/200
# Average train loss: 5.925818, Average validation loss: 268.606659
# EPOCH: 108/200
# Average train loss: 5.749169, Average validation loss: 285.115662
# EPOCH: 109/200
# Average train loss: 5.993473, Average validation loss: 332.518158
# EPOCH: 110/200
# Average train loss: 5.732726, Average validation loss: 269.125397
# EPOCH: 111/200
# Average train loss: 5.770769, Average validation loss: 254.436554
# EPOCH: 112/200
# Average train loss: 5.819399, Average validation loss: 330.504730
# EPOCH: 113/200
# Average train loss: 5.740231, Average validation loss: 286.394379
# EPOCH: 114/200
# Average train loss: 5.746331, Average validation loss: 282.636780
# EPOCH: 115/200
# Average train loss: 5.736023, Average validation loss: 403.913422
# EPOCH: 116/200
# Average train loss: 5.762773, Average validation loss: 285.248444
# EPOCH: 117/200
# Average train loss: 5.601273, Average validation loss: 274.819336
# EPOCH: 118/200
# Average train loss: 5.669515, Average validation loss: 244.524429
# EPOCH: 119/200
# Average train loss: 5.843166, Average validation loss: 243.482727
# EPOCH: 120/200
# Average train loss: 5.739426, Average validation loss: 296.762909
# EPOCH: 121/200
# Average train loss: 5.560926, Average validation loss: 342.754944
# EPOCH: 122/200
# Average train loss: 5.512025, Average validation loss: 241.100296
# EPOCH: 123/200
# Average train loss: 5.561563, Average validation loss: 369.179108
# EPOCH: 124/200
# Average train loss: 5.537422, Average validation loss: 236.223434
# EPOCH: 125/200
# Average train loss: 5.359524, Average validation loss: 357.973816
# EPOCH: 126/200
# Average train loss: 5.394331, Average validation loss: 275.870361
# EPOCH: 127/200
# Average train loss: 5.610290, Average validation loss: 267.015259
# EPOCH: 128/200
# Average train loss: 5.336361, Average validation loss: 284.673035
# EPOCH: 129/200
# Average train loss: 5.286831, Average validation loss: 283.193024
# EPOCH: 130/200
# Average train loss: 5.404397, Average validation loss: 294.957001
# EPOCH: 131/200
# Average train loss: 5.313678, Average validation loss: 209.483047
# EPOCH: 132/200
# Average train loss: 5.358482, Average validation loss: 275.984436
# EPOCH: 133/200
# Average train loss: 5.299264, Average validation loss: 280.843506
# EPOCH: 134/200
# Average train loss: 5.195854, Average validation loss: 216.366364
# EPOCH: 135/200
# Average train loss: 5.193264, Average validation loss: 345.485901
# EPOCH: 136/200
# Average train loss: 5.106363, Average validation loss: 320.155701
# EPOCH: 137/200
# Average train loss: 5.202320, Average validation loss: 250.211472
# EPOCH: 138/200
# Average train loss: 5.239711, Average validation loss: 200.455246
# EPOCH: 139/200
# Average train loss: 5.120396, Average validation loss: 275.748077
# EPOCH: 140/200
# Average train loss: 5.221689, Average validation loss: 191.406830
# EPOCH: 141/200
# Average train loss: 5.170228, Average validation loss: 233.945114
# EPOCH: 142/200
# Average train loss: 5.127844, Average validation loss: 245.515488
# EPOCH: 143/200
# Average train loss: 5.126735, Average validation loss: 206.123672
# EPOCH: 144/200
# Average train loss: 4.998477, Average validation loss: 231.825027
# EPOCH: 145/200
# Average train loss: 4.984828, Average validation loss: 281.651489
# EPOCH: 146/200
# Average train loss: 5.110651, Average validation loss: 235.407700
# EPOCH: 147/200
# Average train loss: 5.136240, Average validation loss: 222.299301
# EPOCH: 148/200
# Average train loss: 5.058868, Average validation loss: 218.875656
# EPOCH: 149/200
# Average train loss: 5.223847, Average validation loss: 191.749557
# EPOCH: 150/200
# Average train loss: 4.866187, Average validation loss: 232.595261
# EPOCH: 151/200
# Average train loss: 4.949815, Average validation loss: 285.518372
# EPOCH: 152/200
# Average train loss: 5.008636, Average validation loss: 285.854889
# EPOCH: 153/200
# Average train loss: 5.076161, Average validation loss: 230.868179
# EPOCH: 154/200
# Average train loss: 4.819950, Average validation loss: 254.869064
# EPOCH: 155/200
# Average train loss: 4.941983, Average validation loss: 291.543091
# EPOCH: 156/200
# Average train loss: 4.963168, Average validation loss: 286.813232
# EPOCH: 157/200
# Average train loss: 4.879313, Average validation loss: 275.245697
# EPOCH: 158/200
# Average train loss: 4.831444, Average validation loss: 209.554337
# EPOCH: 159/200
# Average train loss: 4.880433, Average validation loss: 243.284302
# EPOCH: 160/200
# Average train loss: 4.999191, Average validation loss: 193.986084
# EPOCH: 161/200
# Average train loss: 4.938615, Average validation loss: 217.804153
# EPOCH: 162/200
# Average train loss: 4.776516, Average validation loss: 180.994965
# EPOCH: 163/200
# Average train loss: 4.909522, Average validation loss: 283.314270
# EPOCH: 164/200
# Average train loss: 4.787570, Average validation loss: 193.186081
# EPOCH: 165/200
# Average train loss: 4.767699, Average validation loss: 274.556763
# EPOCH: 166/200
# Average train loss: 4.804388, Average validation loss: 284.183197
# EPOCH: 167/200
# Average train loss: 4.798658, Average validation loss: 202.781921
# EPOCH: 168/200
# Average train loss: 4.794439, Average validation loss: 188.114807
# EPOCH: 169/200
# Average train loss: 4.835161, Average validation loss: 180.744049
# EPOCH: 170/200
# Average train loss: 4.677608, Average validation loss: 205.403183
# EPOCH: 171/200
# Average train loss: 4.652019, Average validation loss: 256.961945
# EPOCH: 172/200
# Average train loss: 4.637906, Average validation loss: 171.663162
# EPOCH: 173/200
# Average train loss: 4.815493, Average validation loss: 192.264709
# EPOCH: 174/200
# Average train loss: 4.603940, Average validation loss: 286.290314
# EPOCH: 175/200
# Average train loss: 4.595411, Average validation loss: 228.562256
# EPOCH: 176/200
# Average train loss: 4.758517, Average validation loss: 235.736877
# EPOCH: 177/200
# Average train loss: 4.680963, Average validation loss: 150.694687
# EPOCH: 178/200
# Average train loss: 4.656961, Average validation loss: 168.237350
# EPOCH: 179/200
# Average train loss: 4.653325, Average validation loss: 219.705688
# EPOCH: 180/200
# Average train loss: 4.548051, Average validation loss: 253.767593
# EPOCH: 181/200
# Average train loss: 4.698363, Average validation loss: 281.811340
# EPOCH: 182/200
# Average train loss: 4.570221, Average validation loss: 218.753494
# EPOCH: 183/200
# Average train loss: 4.577666, Average validation loss: 194.351089
# EPOCH: 184/200
# Average train loss: 4.501837, Average validation loss: 233.267273
# EPOCH: 185/200
# Average train loss: 4.414270, Average validation loss: 216.397781
# EPOCH: 186/200
# Average train loss: 4.567840, Average validation loss: 231.078735
# EPOCH: 187/200
# Average train loss: 4.405396, Average validation loss: 153.456757
# EPOCH: 188/200
# Average train loss: 4.594365, Average validation loss: 171.664627
# EPOCH: 189/200
# Average train loss: 4.508388, Average validation loss: 184.702576
# EPOCH: 190/200
# Average train loss: 4.432432, Average validation loss: 209.647583
# EPOCH: 191/200
# Average train loss: 4.449151, Average validation loss: 152.820663
# EPOCH: 192/200
# Average train loss: 4.430590, Average validation loss: 221.029282
# EPOCH: 193/200
# Average train loss: 4.564941, Average validation loss: 189.933090
# EPOCH: 194/200
# Average train loss: 4.507334, Average validation loss: 141.383408
# EPOCH: 195/200
# Average train loss: 4.477176, Average validation loss: 170.742325
# EPOCH: 196/200
# Average train loss: 4.537061, Average validation loss: 285.407043
# EPOCH: 197/200
# Average train loss: 4.378361, Average validation loss: 148.235565
# EPOCH: 198/200
# Average train loss: 4.345403, Average validation loss: 229.124008
# EPOCH: 199/200
# Average train loss: 4.294231, Average validation loss: 160.326202
# EPOCH: 200/200
# Average train loss: 4.268633, Average validation loss: 250.873444
